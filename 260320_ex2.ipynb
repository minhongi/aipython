# %%
a=7
b=11
c=a
a=b

b=c

# %%
a=7
b=11

# %%
a, b=b, a

# %%
a
# Out:
# 11

# %%
b
# Out:
# 7

# %%
a=input()
# Out:
# 20

# %%
b=input()
# Out:
# 11

# %%
a+b
# Out:
# '2011'

# %%
int(a)-int(b)
# Out:
# 9

# %%
float(a)-float(b)
# Out:
# 9.0

# %%
## 파이썬 산술 연산자

*   `+`: 더하기
*   `-`: 빼기
*   `*`: 곱하기
*   `/`: 나누기
*   `//`: 몫
*   `%`: 나머지
*   `**`: 거듭제곱
# Out:
#   File "/tmp/ipykernel_12449/3264529920.py", line 3
#     *   `+`: 더하기
#         ^
# SyntaxError: invalid syntax

# %%
int(a)
# Out:
# 20

# %%
# Out:
# a값을 입력하시오.20

# %%
a
# Out:
# 20

# %%
age=int(input('나이를 입력하시오.'))
name=input('이름를 입력하시오.')
r=float(input('반지름을 입력하시오.'))
# Out:
# 나이를 입력하시오.20
# 이름를 입력하시오.홍길동
# 반지름을 입력하시오.30

# %%
print('a=', a,'b=', b,'c=', c)
# Out:
# a= 20 b= 11 c= 7

# %%
print('a='.a,end='')
print('b=',b,end='')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_12449/3292406689.py in <cell line: 0>()
# ----> 1 print('a='.a,end='')
#       2 print('b=',b,end='')
#
# AttributeError: 'str' object has no attribute 'a'

# %%
print(f'이름은 {name}이고 나이는 {age} 입니다.')
# Out:
# 이름은 홍길동이고 나이는 20 입니다.

# %%
number=int(input())
hour=int(input())
minute=int(input())
print(f'{number}은 {hour}시간이고 {minute}분 입니다.')
# Out:
# 200
# 3
# 20
# 200은 3시간이고 20분 입니다.

# %%
num=int(input())
if num > 0:
  print('양수입니다.')
else:
  print('음수입니다.')
# Out:
# 10
# 양수입니다.

# %%
total_minutes_input = int(input("총 분을 입력하세요: "))

hours_calculated = total_minutes_input // 60
minutes_calculated = total_minutes_input % 60

print(f'{total_minutes_input}분은 {hours_calculated}시간 {minutes_calculated}분 입니다.')

# %%
coffee_price = 2000
latte_price = 3000
matcha_price = 2500
juice_price = 2800

total_coffee = 1
total_latte = 1
total_matcha = 1  # Fix typo here
total_juice = 1

total_price = coffee_price * total_coffee + latte_price * total_latte + matcha_price * total_matcha + juice_price * total_juice
print(f'총 주문 금액은 {total_price} 입니다.')
# Out:
# 총 주문 금액은 10300 입니다.
