# %%
a=1

# %%
b=2

# %%
c=a+b

# %%
print(b, '+', a, '=', c)
# Out:
# 2 + 1 = 3

# %%
print('반갑습니다.')
print('파이썬입니다.')
print(10 + 20 )
print('10 + 20')
# Out:
# 반갑습니다.
# 파이썬입니다.
# 30
# 10 + 20

# %%
print('2 + 1 = 3')  #출력형식 2+1=3
# Out:
# 2 + 1 = 3
