# %%
i = 0
while i < 5:
  i += 1
  if i == 3:
    continue  ## 루프문의 처음으로 돌아가니까 주의하기
  print(i)
# Out:
# 1
# 2
# 4
# 5

# %%
a = [1, 2, 3]

# %%
a.append(4)

# %%
a
# Out:
# [1, 2, 3, 4, 4]

# %%
fruits = ["apple", "banana", "cherry", "blueberry"]
len(fruits)
# Out:
# 4

# %%
for a in fruits:
  print(a)
# Out:
# apple
# banana
# cherry
# blueberry

# %%
for i, fruit in enumerate(fruits):
  print(f'({i}, {fruit})')
# Out:
# (0, apple)
# (1, banana)
# (2, cherry)
# (3, blueberry)

# %%
kings = ["태조", "정종", "태종", "세종", "문종", "단종", "세조", "예종", "성종",
    "연산군", "중종", "인종", "명종", "선조", "광해군", "인조", "효종", "현종",
    "숙종", "경종", "영조", "정조", "순조", "헌종", "철종", "고종", "순종"]

# 'kings' 리스트와 충돌을 피하기 위해 반복 변수를 '_'로 변경했습니다.
# 사용자 입력을 'user_answer' 변수에 저장하고, 비교 연산자와 문자열 리터럴을 올바르게 사용했습니다.
for _ in range (27):
  user_answer = input('몇 대 왕이냐?')
  if user_answer == "6":
    print('세조입니다.')
    break
# Out:
# 몇 대 왕이냐?9
# 몇 대 왕이냐?10
# 몇 대 왕이냐?6
# 세조입니다.

# %%
len(kings)
# Out:
# 27

# %%
joseon_kings = ["태조", "정종", "태종", "세종", "문종", "단종", "세조", "예종", "성종",
    "연산군", "중종", "인종", "명종", "선조", "광해군", "인조", "효종", "현종",
    "숙종", "경종", "영조", "정조", "순조", "헌종", "철종", "고종", "순종"]

# %%
for i in reversed(joseon_kings):
  print(i)
# Out:
# 태조
# 정종
# 태종
# 세종
# 문종
# 단종
# 세조
# 예종
# 성종
# 연산군
# 중종
# 인종
# 명종
# 선조
# 광해군
# 인조
# 효종
# 현종
# 숙종
# 경종
# 영조
# 정조
# 순조
# 헌종
# 철종
# 고종
# 순종
